# %% [markdown]
# ## Data Analysis

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# Reading document 1
df = pd.read_csv("Roads.csv")

# %%
# Reading document 2
df1 = pd.read_csv("Nigeria_LGAs.csv")

# %%
# Information on the first 20 road
df.head(20)
# Out:
#        osm_id  code        fclass                         name   ref oneway  \
# 0   178678000  5114     secondary                          NaN   NaN      B
# 1   178678001  5114     secondary                          NaN   NaN      B
# 2   178678002  5114     secondary                          NaN   NaN      B
# 3   178678004  5114     secondary                          NaN   NaN      B
# 4   178770907  5121  unclassified                          NaN   NaN      B
# 5   178770908  5121  unclassified                          NaN   NaN      B
# 6   178770909  5122   residential                          NaN   NaN      B
# 7   178770910  5121  unclassified                          NaN   NaN      B
# 8   178770911  5121  unclassified                          NaN   NaN      B
# 9   178772354  5115      tertiary                          NaN   NaN      B
# 10  178772356  5114     secondary                          NaN   NaN      B
# 11  186052105  5112         trunk           Kaduna-Jos Highway  A236      B
# 12  186052112  5115      tertiary                          NaN   NaN      B
# 13  186052127  5115      tertiary                          NaN   NaN      B
# 14  186799174  5113       primary  Rahama to Kafin Mayaki Road  F243      B
# 15  205694168  5112         trunk           Kaduna-Jos Highway  A236      B
# 16  228011802  5115      tertiary                          NaN   NaN      B
# 17  228011803  5121  unclassified                          NaN   NaN      B
# 18  228011804  5121  unclassified                          NaN   NaN      B
# 19  228011805  5121  unclassified                          NaN   NaN      B
#
#     maxspeed  layer bridge tunnel  Length    AREA_SqKM  Road_density
# 0          0      1      T      F   0.115  2157.089074           0.0
# 1          0      1      T      F   0.078  2157.089074           0.0
# 2          0      0      F      F   6.705  2157.089074           3.0
# 3          0      0      F      F  18.708  2157.089074           9.0
# 4          0      0      F      F   0.597  2157.089074           0.0
# 5          0      0      F      F   0.533  2157.089074           0.0
# 6          0      0      F      F   0.454  2157.089074           0.0
# 7          0      0      F      F   7.776  2157.089074           4.0
# 8          0      0      F      F   0.422  2157.089074           0.0
# 9          0      0      F      F  12.082  2157.089074           6.0
# 10         0      0      F      F   9.915  2157.089074           5.0
# 11         0      0      F      F   5.687  2157.089074           3.0
# 12         0      0      F      F   4.159  2157.089074           2.0
# 13         0      0      F      F   3.467  2157.089074           2.0
# 14         0      0      F      F  24.850  2157.089074          12.0
# 15         0      0      F      F  70.780  2157.089074          33.0
# 16         0      0      F      F  15.650  2157.089074           7.0
# 17         0      0      F      F  11.811  2157.089074           5.0
# 18         0      0      F      F   0.880  2157.089074           0.0
# 19         0      0      F      F   3.185  2157.089074           1.0

# %%
# Data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1787576 entries, 0 to 1787575
# Data columns (total 13 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   osm_id        int64
#  1   code          int64
#  2   fclass        object
#  3   name          object
#  4   ref           object
#  5   oneway        object
#  6   maxspeed      int64
#  7   layer         int64
#  8   bridge        object
#  9   tunnel        object
#  10  Length        float64
#  11  AREA_SqKM     float64
#  12  Road_density  float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 177.3+ MB

# %%
# Merging two datasets
df2 = pd.merge(df, df1, on='AREA_SqKM', how='inner')

df2
# Out:
#              osm_id  code        fclass name  ref oneway  maxspeed  layer  \
# 0         178678000  5114     secondary  NaN  NaN      B         0      1
# 1         178678001  5114     secondary  NaN  NaN      B         0      1
# 2         178678002  5114     secondary  NaN  NaN      B         0      0
# 3         178678004  5114     secondary  NaN  NaN      B         0      0
# 4         178770907  5121  unclassified  NaN  NaN      B         0      0
# ...             ...   ...           ...  ...  ...    ...       ...    ...
# 1780520  1467601535  5121  unclassified  NaN  NaN      B         0      0
# 1780521  1469762952  5121  unclassified  NaN  NaN      B         0      0
# 1780522  1473906711  5121  unclassified  NaN  NaN      B         0      0
# 1780523  1473906712  5121  unclassified  NaN  NaN      B         0      0
# 1780524  1473906713  5121  unclassified  NaN  NaN      B         0      0
#
#         bridge tunnel  ...  STATENAME    NAME_1  \
# 0            T      F  ...     Kaduna      Lere
# 1            T      F  ...     Kaduna      Lere
# 2            F      F  ...     Kaduna      Lere
# 3            F      F  ...     Kaduna      Lere
# 4            F      F  ...     Kaduna      Lere
# ...        ...    ...  ...        ...       ...
# 1780520      F      F  ...    Zamfara  Bukkuyum
# 1780521      F      F  ...    Zamfara  Bukkuyum
# 1780522      F      F  ...    Zamfara  Bukkuyum
# 1780523      F      F  ...    Zamfara  Bukkuyum
# 1780524      F      F  ...    Zamfara  Bukkuyum
#
#                                Geo_Politi  Population  Headquarte  MALE_POP  \
# 0        North_Central_Geo-political_Zone    331161.0    Saminaka  172005.0
# 1        North_Central_Geo-political_Zone    331161.0    Saminaka  172005.0
# 2        North_Central_Geo-political_Zone    331161.0    Saminaka  172005.0
# 3        North_Central_Geo-political_Zone    331161.0    Saminaka  172005.0
# 4        North_Central_Geo-political_Zone    331161.0    Saminaka  172005.0
# ...                                   ...         ...         ...       ...
# 1780520     North_West_Geo-political_Zone    211633.0    Bukkuyum  104977.0
# 1780521     North_West_Geo-political_Zone    211633.0    Bukkuyum  104977.0
# 1780522     North_West_Geo-political_Zone    211633.0    Bukkuyum  104977.0
# 1780523     North_West_Geo-political_Zone    211633.0    Bukkuyum  104977.0
# 1780524     North_West_Geo-political_Zone    211633.0    Bukkuyum  104977.0
#
#          FEML_POP                          Source    2006    1991
# 0        159155.0  National Population Commission  339740  331161
# 1        159155.0  National Population Commission  339740  331161
# 2        159155.0  National Population Commission  339740  331161
# 3        159155.0  National Population Commission  339740  331161
# 4        159155.0  National Population Commission  339740  331161
# ...           ...                             ...     ...     ...
# 1780520  106655.0  National Population Commission  216348  211633
# 1780521  106655.0  National Population Commission  216348  211633
# 1780522  106655.0  National Population Commission  216348  211633
# 1780523  106655.0  National Population Commission  216348  211633
# 1780524  106655.0  National Population Commission  216348  211633
#
# [1780525 rows x 25 columns]

# %%
df2 = df2.dropna()

# %%
# Dataset information
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4523 entries, 11 to 1777132
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   osm_id        4523 non-null   int64
#  1   code          4523 non-null   int64
#  2   fclass        4523 non-null   object
#  3   name          4523 non-null   object
#  4   ref           4523 non-null   object
#  5   oneway        4523 non-null   object
#  6   maxspeed      4523 non-null   int64
#  7   layer         4523 non-null   int64
#  8   bridge        4523 non-null   object
#  9   tunnel        4523 non-null   object
#  10  Length        4523 non-null   float64
#  11  AREA_SqKM     4523 non-null   float64
#  12  Road_density  4523 non-null   float64
#  13  OBJECTID_1    4523 non-null   int64
#  14  OBJECTID      4523 non-null   int64
#  15  STATENAME     4523 non-null   object
#  16  NAME_1        4523 non-null   object
#  17  Geo_Politi    4523 non-null   object
#  18  Population    4523 non-null   float64
#  19  Headquarte    4523 non-null   object
#  20  MALE_POP      4523 non-null   float64
#  21  FEML_POP      4523 non-null   float64
#  22  Source        4523 non-null   object
#  23  2006          4523 non-null   int64
#  24  1991          4523 non-null   int64
# dtypes: float64(6), int64(8), object(11)
# memory usage: 918.7+ KB

# %%
# Total Road Length
Total_road_length = df2["Length"].sum()

Total_road_length
# Out:
# np.float64(30944.998)

# %%
# Average road length
Average_road_length = df2["Length"].mean()

Average_road_length
# Out:
# np.float64(6.84169754587663)

# %%
# Road per Capital
df2 ["Road_Per_Capital"] = Total_road_length / df2["Population"]

df2
# Out:
# C:\Users\unity\AppData\Local\Temp\ipykernel_2740\1118846631.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2 ["Road_Per_Capital"] = Total_road_length / df2["Population"]
#             osm_id  code   fclass                         name   ref oneway  \
# 11       186052105  5112    trunk           Kaduna-Jos Highway  A236      B
# 14       186799174  5113  primary  Rahama to Kafin Mayaki Road  F243      B
# 15       205694168  5112    trunk           Kaduna-Jos Highway  A236      B
# 21       241570214  5112    trunk           Kaduna-Jos Highway  A236      B
# 43       276217454  5112    trunk           Kaduna-Jos Highway  A236      B
# ...            ...   ...      ...                          ...   ...    ...
# 1777128  587984672  5113  primary     Gudau - Sabon Birni Road  F218      B
# 1777129  587984673  5113  primary     Gudau - Sabon Birni Road  F218      B
# 1777130  587984674  5113  primary     Gudau - Sabon Birni Road  F218      B
# 1777131  588252847  5113  primary   Kaura Namoda - Jibiya Road  F137      B
# 1777132  588252848  5113  primary   Kaura Namoda - Jibiya Road  F137      B
#
#          maxspeed  layer bridge tunnel  ...  NAME_1  \
# 11              0      0      F      F  ...    Lere
# 14              0      0      F      F  ...    Lere
# 15              0      0      F      F  ...    Lere
# 21              0      1      T      F  ...    Lere
# 43              0      0      F      F  ...    Lere
# ...           ...    ...    ...    ...  ...     ...
# 1777128         0      0      F      F  ...   Zurmi
# 1777129         0      1      T      F  ...   Zurmi
# 1777130         0      0      F      F  ...   Zurmi
# 1777131         0      1      T      F  ...   Zurmi
# 1777132         0      0      F      F  ...   Zurmi
#
#                                Geo_Politi  Population  Headquarte  MALE_POP  \
# 11       North_Central_Geo-political_Zone    331161.0    Saminaka  172005.0
# 14       North_Central_Geo-political_Zone    331161.0    Saminaka  172005.0
# 15       North_Central_Geo-political_Zone    331161.0    Saminaka  172005.0
# 21       North_Central_Geo-political_Zone    331161.0    Saminaka  172005.0
# 43       North_Central_Geo-political_Zone    331161.0    Saminaka  172005.0
# ...                                   ...         ...         ...       ...
# 1777128     North_West_Geo-political_Zone    293837.0       Zurmi  142276.0
# 1777129     North_West_Geo-political_Zone    293837.0       Zurmi  142276.0
# 1777130     North_West_Geo-political_Zone    293837.0       Zurmi  142276.0
# 1777131     North_West_Geo-political_Zone    293837.0       Zurmi  142276.0
# 1777132     North_West_Geo-political_Zone    293837.0       Zurmi  142276.0
#
#          FEML_POP                          Source    2006    1991  \
# 11       159155.0  National Population Commission  339740  331161
# 14       159155.0  National Population Commission  339740  331161
# 15       159155.0  National Population Commission  339740  331161
# 21       159155.0  National Population Commission  339740  331161
# 43       159155.0  National Population Commission  339740  331161
# ...           ...                             ...     ...     ...
# 1777128  151560.0  National Population Commission  293977  293837
# 1777129  151560.0  National Population Commission  293977  293837
# 1777130  151560.0  National Population Commission  293977  293837
# 1777131  151560.0  National Population Commission  293977  293837
# 1777132  151560.0  National Population Commission  293977  293837
#
#         Road_Per_Capital
# 11              0.093444
# 14              0.093444
# 15              0.093444
# 21              0.093444
# 43              0.093444
# ...                  ...
# 1777128         0.105313
# 1777129         0.105313
# 1777130         0.105313
# 1777131         0.105313
# 1777132         0.105313
#
# [4523 rows x 26 columns]

# %%
# Longest road
df2.sort_values('Length', ascending=False)
# Out:
#              osm_id  code   fclass                     name   ref oneway  \
# 1748077   294223401  5113  primary     Nguru to Geidam Road  F128      B
# 1721022   294223401  5113  primary     Nguru to Geidam Road  F128      B
# 1730493   294223401  5113  primary     Nguru to Geidam Road  F128      B
# 1750636   294223401  5113  primary     Nguru to Geidam Road  F128      B
# 720408    560681653  5113  primary          Kano-Gumel Road  F128      B
# ...             ...   ...      ...                      ...   ...    ...
# 1083294   593987861  5113  primary  Abaji to Nassarawa Road  F124      B
# 559193   1433193521  5113  primary         Agbani Link Road  F233      F
# 1562770  1293685378  5112    trunk              Fajuyi Road    A5      F
# 1562774  1293685382  5112    trunk              Fajuyi Road    A5      F
# 1562773  1293685381  5112    trunk              Fajuyi Road    A5      F
#
#          maxspeed  layer bridge tunnel  ...             NAME_1  \
# 1748077         0      0      F      F  ...            Bursari
# 1721022         0      0      F      F  ...             Geidam
# 1730493         0      0      F      F  ...              Barde
# 1750636         0      0      F      F  ...           Yunusari
# 720408          0      0      F      F  ...             Ringim
# ...           ...    ...    ...    ...  ...                ...
# 1083294         0      1      T      F  ...          Nassarawa
# 559193          0      1      T      F  ...        Enugu North
# 1562770         0      1      T      F  ...  Ibadan North West
# 1562774         0      0      F      F  ...  Ibadan North West
# 1562773         0      0      F      F  ...  Ibadan North West
#
#                                Geo_Politi  Population     Headquarte  \
# 1748077     North_East_Geo-political_Zone    109124.0         Dapchi
# 1721022     North_East_Geo-political_Zone    157295.0         Geidam
# 1730493     North_East_Geo-political_Zone    139782.0         Gashua
# 1750636     North_East_Geo-political_Zone    125821.0        Kanamga
# 720408      North_West_Geo-political_Zone    192024.0         Ringim
# ...                                   ...         ...            ...
# 1083294  North_Central_Geo-political_Zone    189835.0      Nassarawa
# 559193      South_East_Geo-political_Zone    244852.0          Enugu
# 1562770     South_West_Geo-political_Zone    152834.0  Dugbe/Onireke
# 1562774     South_West_Geo-political_Zone    152834.0  Dugbe/Onireke
# 1562773     South_West_Geo-political_Zone    152834.0  Dugbe/Onireke
#
#          MALE_POP  FEML_POP                          Source    2006    1991  \
# 1748077   55426.0   53697.0  National Population Commission  109692  109124
# 1721022   82865.0   74429.0  National Population Commission  155740  157295
# 1730493   71163.0   68618.0  National Population Commission  139804  139782
# 1750636   63077.0   62743.0  National Population Commission  125940  125821
# 720408    97678.0   94345.0  National Population Commission  192407  192024
# ...           ...       ...                             ...     ...     ...
# 1083294   94330.0   95504.0  National Population Commission  187220  189835
# 559193   125943.0  118908.0  National Population Commission  242140  244852
# 1562770   75336.0   77497.0  National Population Commission  154029  152834
# 1562774   75336.0   77497.0  National Population Commission  154029  152834
# 1562773   75336.0   77497.0  National Population Commission  154029  152834
#
#         Road_Per_Capital
# 1748077         0.283576
# 1721022         0.196732
# 1730493         0.221380
# 1750636         0.245945
# 720408          0.161152
# ...                  ...
# 1083294         0.163010
# 559193          0.126382
# 1562770         0.202475
# 1562774         0.202475
# 1562773         0.202475
#
# [4523 rows x 26 columns]

# %%
# Road length by LGA
df2.groupby('NAME_1')['Length'].sum()
# Out:
# NAME_1
# Aba North       136.389
# Aba South       157.574
# Abadam          102.340
# Abaji            17.551
# Abak             28.174
#                  ...
# Yunusari        205.873
# Zaki            106.473
# Zaria            22.436
# Zurmi           117.260
# kaduna South    122.250
# Name: Length, Length: 456, dtype: float64

# %%
# Road count by state
df2.groupby('STATENAME').size()
# Out:
# STATENAME
# Abia            88
# Adamawa        109
# Akwa Ibom       71
# Anambra         54
# Bauchi         157
# Bayelsa         60
# Benue           93
# Borno          191
# Cross River     73
# Delta           75
# Ebonyi          68
# Edo             56
# Ekiti           55
# Enugu          132
# FCT, Abuja     100
# Gombe          110
# Imo            114
# Jigawa          79
# Kaduna         219
# Kano           213
# Katsina         94
# Kebbi            4
# Kogi            45
# Kwara          184
# Lagos          522
# Nassarawa       80
# Niger          103
# Ogun           253
# Ondo           114
# Osun            89
# Oyo            243
# Plateau        119
# Rivers         271
# Sokoto          14
# Taraba          60
# Yobe           122
# Zamfara         89
# dtype: int64

# %%
# Roads per 1000 people
df2['road_per_1000'] = df2['Length'] / (df2['Population'] / 1000)
# Out:
# C:\Users\unity\AppData\Local\Temp\ipykernel_2740\903949296.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['road_per_1000'] = df2['Length'] / (df2['Population'] / 1000)

# %%
# Correlation between Population and Length
df2[['Population', 'Length']].corr()
# Out:
#             Population    Length
# Population    1.000000 -0.167849
# Length       -0.167849  1.000000

# %%
gdf = gpd.read_file("Nigerian_LGAs.shp")

# get centroid coordinates
gdf["lon"] = gdf.geometry.centroid.x
gdf["lat"] = gdf.geometry.centroid.y

# export to CSV
gdf[["NAME_1", "lat", "lon"]].to_csv("nigeria_states_coordinates.csv", index=False)
# Out:
# C:\Users\unity\AppData\Local\Temp\ipykernel_2740\2952023825.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["lon"] = gdf.geometry.centroid.x
# C:\Users\unity\AppData\Local\Temp\ipykernel_2740\2952023825.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["lat"] = gdf.geometry.centroid.y

# %%
df3 = pd.read_csv("nigeria_states_coordinates.csv")
df3
# Out:
#                   NAME_1        lat       lon
# 0                   Lere  10.357251  8.572471
# 1                  Zaria  11.037522  7.705616
# 2           Zangon-Kataf   9.840436  8.236580
# 3           Birnin-Gwari  10.875143  6.643603
# 4                  Sanga   9.238397  8.500706
# ..                   ...        ...       ...
# 769  Birnin Magaji/Kiyaw  12.435537  6.895482
# 770                Gusau  11.810687  6.736948
# 771             Shinkafi  13.029946  6.497544
# 772                Zurmi  12.816470  6.767603
# 773             Bukkuyum  11.947356  5.580757
#
# [774 rows x 3 columns]

# %%
df3 = pd.merge(df2, df3, on='NAME_1', how='inner')

# %% [markdown]
# ## Data Visualization

# %%
df4 = df3.groupby('NAME_1')[['Length']].sum()
top_LGA = df4.nlargest(10, 'Length')
top_LGA
# Out:
#                 Length
# NAME_1
# Nassarawa      392.320
# Kachia         365.501
# Damaturu       323.930
# Mobbar         257.537
# Potiskum       255.431
# Shagamu        246.665
# Umuahia North  244.818
# Bursari        230.525
# Konduga        228.103
# Gubio          227.382

# %%
# Barchart showing the top 10 LGAs by Road
top_LGA.plot(kind = 'bar', color = 'orange')
plt.ylabel('Length of road')
plt.xlabel('LGA')
plt.title('Top 10 LGAs by Road')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df5 = df3.groupby('NAME_1')[['Length']].sum()
top_LGA = df5.nlargest(10, 'Length')
top_LGA
# Out:
#                 Length
# NAME_1
# Nassarawa      392.320
# Kachia         365.501
# Damaturu       323.930
# Mobbar         257.537
# Potiskum       255.431
# Shagamu        246.665
# Umuahia North  244.818
# Bursari        230.525
# Konduga        228.103
# Gubio          227.382

# %%
# Histogram showing Road Length Distribution
top_LGA.plot(kind = 'hist', color = 'red')
plt.ylabel('Frequency')
plt.xlabel('Length of road')
plt.title('Road Length Distribution')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df6 = df3.groupby('fclass')[['Population']].sum()
df6
# Out:
#                 Population
# fclass
# motorway       204786837.0
# motorway_link    9971115.0
# primary        457108071.0
# residential       116654.0
# secondary       47820213.0
# service           857162.0
# tertiary         2028136.0
# track             582289.0
# trunk          481458289.0
# trunk_link       5391932.0
# unclassified     1619611.0

# %%
# Plotting Infrastructure against Population
plt.scatter("fclass", "Population")
plt.title('Infrastructure against Population')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df3.to_csv("Abuja Road Network.csv")
